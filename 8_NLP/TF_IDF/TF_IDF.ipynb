# %% [markdown]
# # TF-IDF

# %%
Document1 ='It is going to rain roday.'
Document2 ='Today I am not going outside.'
Document3 ='I am going to watch the season premiere.'
Doc = [Document1 ,Document2,Document3]
print(Doc)
# Out:
# ['It is going to rain roday.', 'Today I am not going outside.', 'I am going to watch the season premiere.']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer= TfidfVectorizer()

# %%
analyze = vectorizer.build_analyzer()
print('Document 1',analyze(Document1))
print('Document 2',analyze(Document2))
print('Document 3',analyze(Document3))

X = vectorizer.fit_transform(Doc)
print(vectorizer.get_feature_names_out())
print('Document transform',X.toarray())
# Out:
# Document 1 ['it', 'is', 'going', 'to', 'rain', 'roday']
# Document 2 ['today', 'am', 'not', 'going', 'outside']
# Document 3 ['am', 'going', 'to', 'watch', 'the', 'season', 'premiere']
# ['am' 'going' 'is' 'it' 'not' 'outside' 'premiere' 'rain' 'roday' 'season'
#  'the' 'to' 'today' 'watch']
# Document transform [[0.         0.26607496 0.45050407 0.45050407 0.         0.
#   0.         0.45050407 0.45050407 0.         0.         0.34261996
#   0.         0.        ]
#  [0.38376993 0.29803159 0.         0.         0.50461134 0.50461134
#   0.         0.         0.         0.         0.         0.
#   0.50461134 0.        ]
#  [0.32412354 0.25171084 0.         0.         0.         0.
#   0.4261835  0.         0.         0.4261835  0.4261835  0.32412354
#   0.         0.4261835 ]]

# %% [markdown]
# # TF-IDF with explanation

# %%
import pandas as pd
import sklearn as sk
import math

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import re
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
first_sentence = "data science is the hotest job of the 21st century"
second_sentence = "machine learning is the key for data science"

# %%
#split so each word have their own string
first_sentence = first_sentence.split(" ")
second_sentence = second_sentence.split(" ")#join the

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop_words = set(stopwords.words('english'))
print(stop_words)
first_sentence = [w for w in first_sentence if not w in stop_words]
second_sentence = [w for w in second_sentence if not w in stop_words]
print(first_sentence)
print(second_sentence)
# Out:
# {'will', "shan't", 'he', "needn't", "doesn't", 'won', 'if', 'in', 'when', "you've", "she's", 'be', 'do', 'the', 'ours', 'been', 's', 'both', 'with', 'very', "wasn't", 'their', 'was', 'so', 'aren', 'theirs', 'where', 'have', 'into', "couldn't", "hasn't", 'its', 'after', 'don', 'but', 'can', 're', 'wouldn', "weren't", 'has', 'isn', 'over', 'for', 'between', 'should', "you'd", 'only', 'my', 'shan', 'those', 'we', 'now', 'nor', 'doesn', 'these', 'at', 'shouldn', 'most', 'had', 'during', 'needn', 'ain', 'him', 'other', 'same', 'because', 'what', 'about', "it's", 'under', 'yourself', 'against', 'not', 'myself', 'am', 'hers', 'until', 'just', 'didn', 'each', 'by', 'off', 'haven', 'is', 'themselves', 'and', 'itself', "shouldn't", "mustn't", 'you', 'own', "don't", 'll', 'few', 'there', "won't", 'whom', 'before', 'some', 'doing', 'd', 'they', 'as', 'too', "mightn't", "should've", 'why', 'than', "you'll", 'me', 'this', 'being', 'up', 'from', 'having', 'out', 'does', "wouldn't", 'mightn', 'which', 'here', 'no', 'a', 'below', 'that', 'yours', "you're", 'to', 'all', 'them', 'i', 'above', 've', 'she', 'further', 'his', 'm', 'of', 'or', 'himself', 'once', 'hadn', 'hasn', 'mustn', 'it', 'then', 'wasn', 'weren', 'ourselves', 'our', "didn't", 'through', 'her', 'o', 'an', 'yourselves', 'down', 'couldn', 'any', 'who', 'y', "isn't", 't', 'while', 'are', "hadn't", "haven't", 'were', "that'll", "aren't", 'ma', 'more', 'herself', 'did', 'on', 'again', 'such', 'your', 'how'}
# ['data', 'science', 'hotest', 'job', '21st', 'century']
# ['machine', 'learning', 'key', 'data', 'science']

# %%
total= set(first_sentence).union(set(second_sentence))

print(total)
# Out:
# {'key', '21st', 'machine', 'science', 'learning', 'job', 'century', 'hotest', 'data'}

# %%
wordDictA = dict.fromkeys(total, 0)
wordDictB = dict.fromkeys(total, 0)
for word in first_sentence:
    wordDictA[word]+=1

# %%
for word in second_sentence:
    wordDictB[word]+=1

# %%
print(wordDictA)
print(wordDictB)
# Out:
# {'key': 0, '21st': 1, 'machine': 0, 'science': 1, 'learning': 0, 'job': 1, 'century': 1, 'hotest': 1, 'data': 1}
# {'key': 1, '21st': 0, 'machine': 1, 'science': 1, 'learning': 1, 'job': 0, 'century': 0, 'hotest': 0, 'data': 1}

# %%
pd.DataFrame([wordDictA, wordDictB])
# Out:
#    key  21st  machine  science  learning  job  century  hotest  data
# 0    0     1        0        1         0    1        1       1     1
# 1    1     0        1        1         1    0        0       0     1

# %%
from numpy import log10
def computeTF(wordDict, doc):
    tfDict = {}
    corpusCount = len(doc)
    for word, count in wordDict.items():
        tfDict[word] = count/float(corpusCount)
    return(tfDict)

# %%
#running our sentences through the tf function:
tfFirst = computeTF(wordDictA, first_sentence)
tfSecond = computeTF(wordDictB, second_sentence)

# %%
#Converting to dataframe for visualization
tf = pd.DataFrame([tfFirst, tfSecond])
tf = 1 + log10(tf)
tf
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py:351: RuntimeWarning: divide by zero encountered in log10
#   result = func(self.values, **kwargs)
#        key      21st  machine   science  learning       job   century  \
# 0     -inf  0.221849     -inf  0.221849      -inf  0.221849  0.221849
# 1  0.30103      -inf  0.30103  0.301030   0.30103      -inf      -inf
#
#      hotest      data
# 0  0.221849  0.221849
# 1      -inf  0.301030

# %%
def computeIDF(docList):
    idfDict = {}
    N = len(docList)

    idfDict = dict.fromkeys(docList[0].keys(), 0)
    for word, val in idfDict.items():
        #print(word, val)
        idfDict[word] = math.log10(N / (float(val) + 1 ))

    return(idfDict)

# %%
#inputing our sentences in the log file
idfs = computeIDF([wordDictA, wordDictB])
idfs
# Out:
# {'key': 0.3010299956639812,
#  '21st': 0.3010299956639812,
#  'machine': 0.3010299956639812,
#  'science': 0.3010299956639812,
#  'learning': 0.3010299956639812,
#  'job': 0.3010299956639812,
#  'century': 0.3010299956639812,
#  'hotest': 0.3010299956639812,
#  'data': 0.3010299956639812}

# %%
def computeTFIDF(tfBow, idfs):
    tfidf = {}
    for word, val in tfBow.items():
        tfidf[word] = val*idfs[word]
    return(tfidf)
#running our two sentences through the IDF:
idfFirst = computeTFIDF(tfFirst, idfs)
idfSecond = computeTFIDF(tfSecond, idfs)
#putting it in a dataframe
idf= pd.DataFrame([idfFirst, idfSecond])
print(idf)
# Out:
#         key      21st   machine   science  learning       job   century  \
# 0  0.000000  0.050172  0.000000  0.050172  0.000000  0.050172  0.050172
# 1  0.060206  0.000000  0.060206  0.060206  0.060206  0.000000  0.000000
#
#      hotest      data
# 0  0.050172  0.050172
# 1  0.000000  0.060206
