# %% [markdown]
# **One Hot Trining Encoding**

# %% [markdown]
# **Step 1: Create the dataset**

# %%
import pandas as pd

# create data frame

df=pd.DataFrame({'team':['A','A','B','B','B','B','C','C'],
                 'points':[25,12,15,14,19,23,25,29]})

# view data frame

df
# Out:
#   team  points
# 0    A      25
# 1    A      12
# 2    B      15
# 3    B      14
# 4    B      19
# 5    B      23
# 6    C      25
# 7    C      29

# %%
from sklearn.preprocessing import OneHotEncoder
encoder= OneHotEncoder(handle_unknown='ignore')
encoder_df=pd.DataFrame(encoder.fit_transform(df[['team']]).toarray())
final_df=df.join(encoder_df)
print(final_df)
# Out:
#   team  points    0    1    2
# 0    A      25  1.0  0.0  0.0
# 1    A      12  1.0  0.0  0.0
# 2    B      15  0.0  1.0  0.0
# 3    B      14  0.0  1.0  0.0
# 4    B      19  0.0  1.0  0.0
# 5    B      23  0.0  1.0  0.0
# 6    C      25  0.0  0.0  1.0
# 7    C      29  0.0  0.0  1.0

# %%
final_df.drop('team',axis=1,inplace=True)
print(final_df)
# Out:
#    points    0    1    2
# 0      25  1.0  0.0  0.0
# 1      12  1.0  0.0  0.0
# 2      15  0.0  1.0  0.0
# 3      14  0.0  1.0  0.0
# 4      19  0.0  1.0  0.0
# 5      23  0.0  1.0  0.0
# 6      25  0.0  0.0  1.0
# 7      29  0.0  0.0  1.0

# %% [markdown]
# **we could also rename the columns**

# %%
final_df.columns=['points','teamA','teamb','teamc']
print(final_df)
# Out:
#    points  teamA  teamb  teamc
# 0      25    1.0    0.0    0.0
# 1      12    1.0    0.0    0.0
# 2      15    0.0    1.0    0.0
# 3      14    0.0    1.0    0.0
# 4      19    0.0    1.0    0.0
# 5      23    0.0    1.0    0.0
# 6      25    0.0    0.0    1.0
# 7      29    0.0    0.0    1.0
